# %%
url='http://127.0.0.1:8000/sse'

# %%
pip install pydantic-ai[mcp]
# Out:
# Requirement already satisfied: pydantic-ai[mcp] in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.22.0)
# WARNING: pydantic-ai 1.22.0 does not provide the extra 'mcp'
# Requirement already satisfied: pydantic-ai-slim==1.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.22.0)
# Requirement already satisfied: genai-prices>=0.0.40 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.0.45)
# Requirement already satisfied: griffe>=1.3.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.15.0)
# Requirement already satisfied: httpx>=0.27 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.38.0)
# Requirement already satisfied: pydantic-graph==1.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.22.0)
# Requirement already satisfied: pydantic>=2.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.12.4)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.4.2)
# Requirement already satisfied: ag-ui-protocol>=0.1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.1.10)
# Requirement already satisfied: starlette>=0.45.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.50.0)
# Requirement already satisfied: anthropic>=0.70.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.75.0)
# Requirement already satisfied: boto3>=1.40.14 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.41.3)
# Requirement already satisfied: argcomplete>=3.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.6.3)
# Requirement already satisfied: prompt-toolkit>=3 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.0.52)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.11.0)
# Requirement already satisfied: rich>=13 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (14.2.0)
# Requirement already satisfied: cohere>=5.18.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (5.20.0)
# Requirement already satisfied: pydantic-evals==1.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.22.0)
# Requirement already satisfied: fastmcp>=2.12.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.13.1)
# Requirement already satisfied: google-genai>=1.51.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.52.0)
# Requirement already satisfied: groq>=0.25.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.36.0)
# Requirement already satisfied: huggingface-hub>=0.33.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.1.5)
# Requirement already satisfied: logfire>=3.14.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.15.1)
# Requirement already satisfied: mcp>=1.18.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.22.0)
# Requirement already satisfied: mistralai>=1.9.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.9.11)
# Requirement already satisfied: openai>=1.107.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.8.1)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (9.1.2)
# Requirement already satisfied: temporalio==1.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.19.0)
# Requirement already satisfied: google-auth>=2.36.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.43.0)
# Requirement already satisfied: requests>=2.32.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.32.5)
# Requirement already satisfied: anyio>=0 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-evals==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.11.0)
# Requirement already satisfied: logfire-api>=3.14.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic-evals==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.15.1)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-evals==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (6.0.3)
# Requirement already satisfied: nexus-rpc==1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from temporalio==1.19.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.1.0)
# Requirement already satisfied: protobuf<7.0.0,>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from temporalio==1.19.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (6.33.1)
# Requirement already satisfied: types-protobuf>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from temporalio==1.19.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (6.32.1.20251105)
# Requirement already satisfied: typing-extensions<5,>=4.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from temporalio==1.19.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.10->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2.10->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.41.5)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.17.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.12.0)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from anthropic>=0.70.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio>=0->pydantic-evals==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.11)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.16.0)
# Requirement already satisfied: botocore<1.42.0,>=1.41.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.41.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.42.0,>=1.41.3->boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.42.0,>=1.41.3->boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.3->boto3>=1.40.14->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.17.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.12.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.4.0)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.22.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cohere>=5.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.32.4.20250913)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.32.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.4.4)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (25.0)
# Requirement already satisfied: shellingham in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.67.1)
# Requirement already satisfied: typer-slim in /usr/local/python/3.12.1/lib/python3.12/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.20.0)
# Requirement already satisfied: authlib>=1.6.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.6.5)
# Requirement already satisfied: cyclopts>=4.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.3.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.3.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.3.4)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.5.0)
# Requirement already satisfied: py-key-value-aio<0.3.0,>=0.2.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.2.8)
# Requirement already satisfied: python-dotenv>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.2.1)
# Requirement already satisfied: uvicorn>=0.35 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.38.0)
# Requirement already satisfied: websockets>=15.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (15.0.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/codespace/.local/lib/python3.12/site-packages (from mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.0.3)
# Requirement already satisfied: beartype>=0.22.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio<0.3.0,>=0.2.8->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.22.6)
# Requirement already satisfied: py-key-value-shared==0.2.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio<0.3.0,>=0.2.8->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.2.8)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (25.7.0)
# Requirement already satisfied: cachetools>=6.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (6.2.2)
# Requirement already satisfied: cryptography in /usr/local/python/3.12.1/lib/python3.12/site-packages (from authlib>=1.6.5->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (46.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from cyclopts>=4.0.0->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (25.4.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from cyclopts>=4.0.0->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.3.2)
# Requirement already satisfied: docutils in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.22.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.6.1)
# Requirement already satisfied: colorama>=0.4 in /home/codespace/.local/lib/python3.12/site-packages (from griffe>=1.3.2->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.4.6)
# WARNING: huggingface-hub 1.1.5 does not provide the extra 'inference'
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.28.0)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jsonschema-path>=0.3.4->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.4.4)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/python/3.12.1/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/python/3.12.1/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.3.0)
# Requirement already satisfied: jaraco.context in /usr/local/python/3.12.1/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (6.0.1)
# Requirement already satisfied: executing>=2.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.2.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation>=0.41b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.35.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.38.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==1.22.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk<1.39.0,>=1.35.0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-httpx>=0.42b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.59b0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mistralai>=1.9.10->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.3.0)
# Requirement already satisfied: invoke<3.0.0,>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mistralai>=1.9.10->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.2.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire>=3.14.1->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (1.17.3)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-instrumentation-httpx>=0.42b0->logfire[httpx]>=3.14.1; extra == "logfire"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.59b0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.2.14)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.8.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography->authlib>=1.6.5->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.5->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (0.1.2)
# Requirement already satisfied: click>=7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from uvicorn>=0.35->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (8.3.1)
# Requirement already satisfied: more-itertools in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp>=2.12.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,fastmcp,google,groq,huggingface,logfire,mcp,mistral,openai,retries,temporal,ui,vertexai]==1.22.0->pydantic-ai[mcp]) (10.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydantic_ai import Agent
from pydantic_ai.mcp import MCPServerStdio
from toyaikit.chat.interface import StdOutputInterface
from toyaikit.chat.runners import PydanticAIRunner

# %%
from pydantic_ai.mcp import MCPServerSSE

mcp_client = MCPServerSSE(
    url='http://127.0.0.1:8000/sse'
)

# %%
developer_prompt = """
You're a course teaching assistant. 
You're given a question from a course student and your task is to answer it.

If you want to look up the answer, explain why before making the call. Use as many 
keywords from the user question as possible when making first requests.

Make multiple searches. Try to expand your search by using new keywords based on the results you
get from the search.

At the end, make a clarifying question based on what you presented and ask if there are 
other areas that the user wants to explore.
""".strip()


agent = Agent(
    name="faq_agent",
    instructions=developer_prompt,
    toolsets=[mcp_client],
    model='gpt-4o-mini'
)

# %%
result = await agent.run('how do i run kafka in python')
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3697, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "/tmp/ipykernel_2142/1624267392.py", line 1, in <module>
#   |     result = await agent.run('how do i run kafka in python')
#   |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic_ai/agent/abstract.py", line 225, in run
#   |     async with self.iter(
#   |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic_ai/agent/__init__.py", line 656, in iter
#   |     async with toolset:
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic_ai/toolsets/combined.py", line 51, in __aenter__
#   |     await exit_stack.enter_async_context(toolset)
#   |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 659, in enter_async_context
#   |     result = await _enter(cm)
#   |              ^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic_ai/mcp.py", line 623, in __aenter__
#   |     self._read_stream, self._write_stream = await exit_stack.enter_async_context(self.client_streams())
#   |                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 659, in enter_async_context
#   |     result = await _enter(cm)
#   |              ^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/pydantic_ai/mcp.py", line 1060, in client_streams
#   |     async with transport_client_partial(headers=self.headers) as (read_stream, write_stream, *_):
#   |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 210, in __aenter__
#   |     return await anext(self.gen)
#   |            ^^^^^^^^^^^^^^^^^^^^^
#   |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/mcp/client/sse.py", line 55, in sse_client
#   |     async with anyio.create_task_group() as tg:
#   |   File "/home/codespace/.local/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 781, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     |     yield
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_transports/default.py", line 394, in handle_async_request
#     |     resp = await self._pool.handle_async_request(req)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_async/connection_pool.py", line 256, in handle_async_request
#     |     raise exc from None
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_async/connection_pool.py", line 236, in handle_async_request
#     |     response = await connection.handle_async_request(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_async/connection.py", line 101, in handle_async_request
#     |     raise exc
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_async/connection.py", line 78, in handle_async_request
#     |     stream = await self._connect(request)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_async/connection.py", line 124, in _connect
#     |     stream = await self._network_backend.connect_tcp(**kwargs)
#     |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_backends/auto.py", line 31, in connect_tcp
#     |     return await self._backend.connect_tcp(
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_backends/anyio.py", line 113, in connect_tcp
#     |     with map_exceptions(exc_map):
#     |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(value)
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpcore/_exceptions.py", line 14, in map_exceptions
#     |     raise to_exc(exc) from exc
#     | httpcore.ConnectError: All connection attempts failed
#     |
#     | The above exception was the direct cause of the following exception:
#     |
#     | Traceback (most recent call last):
#     |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/mcp/client/sse.py", line 61, in sse_client
#     |     async with aconnect_sse(
#     |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 210, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/usr/local/python/3.12.1/lib/python3.12/site-packages/httpx_sse/_api.py", line 69, in aconnect_sse
#     |     async with client.stream(method, url, headers=headers, **kwargs) as response:
#     |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 210, in __aenter__
#     |     return await anext(self.gen)
#     |            ^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_client.py", line 1583, in stream
#     |     response = await self.send(
#     |                ^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_client.py", line 1629, in send
#     |     response = await self._send_handling_auth(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_client.py", line 1657, in _send_handling_auth
#     |     response = await self._send_handling_redirects(
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_client.py", line 1694, in _send_handling_redirects
#     |     response = await self._send_single_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_client.py", line 1730, in _send_single_request
#     |     response = await transport.handle_async_request(request)
#     |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_transports/default.py", line 393, in handle_async_request
#     |     with map_httpcore_exceptions():
#     |   File "/usr/local/python/3.12.1/lib/python3.12/contextlib.py", line 158, in __exit__
#     |     self.gen.throw(value)
#     |   File "/home/codespace/.local/lib/python3.12/site-packages/httpx/_transports/default.py", line 118, in map_httpcore_exceptions
#     |     raise mapped_exc(message) from exc
#     | httpx.ConnectError: All connection attempts failed
#     +------------------------------------
